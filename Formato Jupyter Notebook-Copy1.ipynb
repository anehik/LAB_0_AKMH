# %% [markdown]
# <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg">

# %% [markdown]
# <center> <font color= #004A94> <font size = 6> Lic. Ingeniería Financiera </font> <br> <br> <font color= #047CFB> <font size = 4>I.F. Anehi Karely Mayorquin Higuera - if707468@iteso.mx </font>

# %% [markdown]
# <center><font color= #004A94> <font size = 6> Microestructura y Sistemas de Trading </font> <br> <br>

# %% [markdown]
# <center><font color=#42c29b><font size=5> Laboratorio 0: Herramientas Computacionales </font> <br> <br>

# %% [markdown]
# <center> <font color= #047CFB> <font size = 4> Primavera 2020 </font>  |  <font color= #047CFB> <font size = 4> Repositorio: <a href='https://github.com/anehik/LAB_0_AKMH.git'>Link</a></font>

# %% [markdown]
# ---

# %% [markdown]
# # Resumen:

# %% [markdown]
# <font size=4>Este laboratorio sirve para generar nueva información de los precios a partir de los históricos en formato  OHLC (Open, High, Low, Close). Esta nueva información generada, la mayoría almacenada como nuevas columnas dentro del DataFrame que contiene los precios históricos OHLC, puede ser utilizada también como "variables explicativas" en modelos predictivos (ya sean de regresión o de clasificación). El enfóque de los cálculos que deberás de realizar para este laboratorio es "estadístico" utilizando información de las "velas".  También vas a poner en práctica algunos códigos simples para graficar utilizando la librería de Plotly, todo esto utilizando una lógica de organizar el código con base a "funciones" y scripts separados (algo bastante útil para proyectos aplicados de python).</font> <br>

# %% [markdown]
# # Codigo:

# %%
import datetime
import pandas as pd
import numpy as np

# %%
import funciones as fn                              # Para procesamiento de datos
import visualizaciones as vs                        # Para visualizacion de datos
import pandas as pd                                 # Procesamiento de datos
from datos import OA_Ak                             # Importar token para API de OANDA
import matplotlib.pyplot as plt
import plotly.express as px                         # Para la gráfica interactiva 
import plotly.graph_objects as go

# %%
# -- --------------------------------------------------------- Descargar precios de OANDA -- #

# token de OANDA
OA_In = "EUR_USD"                  # Instrumento
OA_Gn = "H1"                        # Granularidad de velas
fini = pd.to_datetime("2019-07-06 00:00:00").tz_localize('GMT')  # Fecha inicial
ffin = pd.to_datetime("2019-12-06 00:00:00").tz_localize('GMT')  # Fecha final

# %%
# Descargar precios masivos
df_pe = fn.f_precios_masivos(p0_fini=fini, p1_ffin=ffin, p2_gran=OA_Gn,
                             p3_inst=OA_In, p4_oatk=OA_Ak, p5_ginc=4900)

# %%
# -- --------------------------------------------------------------- Graficar OHLC plotly -- #

vs_grafica1 = vs.g_velas(p0_de=df_pe.iloc[0:120, :])
vs_grafica1.show()

# %%
# -- ------------------------------------------------------------------- Conteno de velas -- #

# multiplicador de precios
pip_mult = 10000
    #Las funciones contenidas en el ejemplo visto en clase fueron:
    #['hora'] : Hora de la vela
    
# -- 0A.1: Hora
df_pe['hora'] = [df_pe['TimeStamp'][i].hour for i in range(0, len(df_pe['TimeStamp']))]

    #La hora expresada en formato de 24hrs, en la que ocurrió la vela.
    #['dia'] : Dia de la semana de la vela

# -- 0A.2: Dia de la semana.
df_pe['dia'] = [df_pe['TimeStamp'][i].weekday() for i in range(0, len(df_pe['TimeStamp']))]

    #Día de la semana en formato numérico (0 = domingo, 1 = lunes, etc), en el que ocurrió la vela.
    #vs.g_boxplot: Boxplot de amplitud de velas (close - open).

# -- 0B: Boxplot de amplitud de velas (close - open).
df_pe['co'] = (df_pe['Close'] - df_pe['Open'])*pip_mult

# %%
# -- ------------------------------------------------------------ Graficar Boxplot plotly -- #
vs_grafica2 = vs.g_boxplot_varios(p0_data=df_pe[['co']], p1_norm=False)
vs_grafica2.show()

# %% [markdown]
# # EJERCICIO 1

# %% [markdown]
# <font size=4>(1pt) ['mes'] : Mes en el que ocurrió la vela.
#
# Utilizando la columna de TimeStamp calcula el "Mes" en el que ocurrió la vela.

# %%
#--- primer ejercicio. Mes en el que ocurrió la vela.
df_pe['mes'] = [df_pe['TimeStamp'][i].month for i in range(0, len(df_pe['TimeStamp']))]

# %% [markdown]
# # EJERCICIO 2

# %% [markdown]
# <font size=4>(1pt) ['sesion'] : Sesion de la vela
# Sesión bursátil en la que ocurrió la vela,  el valor dentro de la columna deberás de colocarlo siguiendo la siguiente regla:
#
#     •	'asia':  si en la columna ['hora'] tiene alguno de estos valores -> 22, 23, 0, 1, 2, 3, 4, 5, 6, 7
#
#     •	'asia_europa': si en la columna ['hora'] tiene alguno de estos valores -> 8
#
#     •	'europa': si en la columna ['hora'] tiene alguno de estos valores -> 9, 10, 11, 12
#
#     •	'europa_america': si en la columna ['hora'] tiene alguno de estos valores -> 13, 14, 15, 16
#
#     •	'america': si en la columna ['hora'] tiene alguno de estos valores -> 17, 18, 19, 20, 21
#
# Recuerda que el ['TimeStamp'] de los precios que están descargándose en el código está en huso horario UTC, así que no aplicará a las horas de Guadalajara", sino, a las horas de cualquier centro bursátil que esté bajo el huso horario UTC, como lo es el caso de Londres que tiene huso horario GMT = 0.

# %%
#--- Segundo ejercicio. Sesion de la vela

def sesion_vela(hora):
    if hora==22 or hora==23 or hora==0 or hora==1 or hora==2 or hora==3 or hora==4 or hora==5 or hora==6 or hora==7:
        ans = 'asia'
    elif hora==8 :
        ans= 'asia_europa'
    elif hora==9 or hora==10 or hora== 11 or hora== 12:
        ans ='europa'
    elif hora == 13 or hora == 14 or hora == 15 or hora == 16:
        ans= 'europa_americana'
    else:
        ans = 'americana'
    return ans

# %%
df_pe['sesion_vela'] = [sesion_vela(int(df_pe['hora'][i])) for i in range(0, len(df_pe['hora']))]

# %%
df_pe.head()
# Out:
#             TimeStamp     Open     High      Low    Close  hora  dia   co  \
# 0 2019-07-07 21:00:00  1.12248  1.12275  1.12240  1.12275    21    6  2.7
# 1 2019-07-07 22:00:00  1.12278  1.12292  1.12256  1.12288    22    6  1.0
# 2 2019-07-07 23:00:00  1.12286  1.12286  1.12266  1.12268    23    6 -1.8
# 3 2019-07-08 00:00:00  1.12270  1.12298  1.12198  1.12212     0    0 -5.8
# 4 2019-07-08 01:00:00  1.12214  1.12283  1.12210  1.12276     1    0  6.2
#
#    mes sesion_vela
# 0    7   americana
# 1    7        asia
# 2    7        asia
# 3    7        asia
# 4    7        asia

# %% [markdown]
# # EJERCICIO 3

# %% [markdown]
# <font size=4>(1pt) ['oc']: Amplitud de vela (en pips).
#
# Calcular la diferencia entre las columnas ['Open'] y ['Close'], expresarla en pips.

# %%
#--- Tercer ejercicio. Amplitud de vela.

# %%
df_pe['Amplitud de vela'] = (df_pe['Open'] - df_pe['Close'])*pip_mult

# %%
df_pe.head()
# Out:
#             TimeStamp     Open     High      Low    Close  hora  dia   co  \
# 0 2019-07-07 21:00:00  1.12248  1.12275  1.12240  1.12275    21    6  2.7
# 1 2019-07-07 22:00:00  1.12278  1.12292  1.12256  1.12288    22    6  1.0
# 2 2019-07-07 23:00:00  1.12286  1.12286  1.12266  1.12268    23    6 -1.8
# 3 2019-07-08 00:00:00  1.12270  1.12298  1.12198  1.12212     0    0 -5.8
# 4 2019-07-08 01:00:00  1.12214  1.12283  1.12210  1.12276     1    0  6.2
#
#    mes sesion_vela  Amplitud de vela
# 0    7   americana              -2.7
# 1    7        asia              -1.0
# 2    7        asia               1.8
# 3    7        asia               5.8
# 4    7        asia              -6.2

# %% [markdown]
# # EJERCICIO 4

# %% [markdown]
# <font size=4>(1pt) ['hl']: Amplitud de extremos (en pips).
#
# Calcular la diferencia entre las columnas ['High'] y ['Low'], expresarla en pips.

# %%
#---Cuarto Ejercicio. Amplitud de extremos

# %%
df_pe['HL'] = (df_pe['High'] - df_pe['Low'])*pip_mult

# %%
df_pe.head()
# Out:
#             TimeStamp     Open     High      Low    Close  hora  dia   co  \
# 0 2019-07-07 21:00:00  1.12248  1.12275  1.12240  1.12275    21    6  2.7
# 1 2019-07-07 22:00:00  1.12278  1.12292  1.12256  1.12288    22    6  1.0
# 2 2019-07-07 23:00:00  1.12286  1.12286  1.12266  1.12268    23    6 -1.8
# 3 2019-07-08 00:00:00  1.12270  1.12298  1.12198  1.12212     0    0 -5.8
# 4 2019-07-08 01:00:00  1.12214  1.12283  1.12210  1.12276     1    0  6.2
#
#    mes sesion_vela  Amplitud de vela    HL
# 0    7   americana              -2.7   3.5
# 1    7        asia              -1.0   3.6
# 2    7        asia               1.8   2.0
# 3    7        asia               5.8  10.0
# 4    7        asia              -6.2   7.3

# %% [markdown]
# # EJERCICIO 5

# %% [markdown]
# <font size=4> (.5pt) ['sentido'] : Sentido de la vela (alcista o bajista)
#
# En esta columna debes de asignarle el valor de 'alcista' para cuando ['Close'] >= ['Open'] y 'bajista' en el caso contrario.

# %%
#En esta parte, se hacen listas comprimidas para identificar cuales velas estan a la alza y cuales a la baja
df_pe['Alcista o bajista'] = ['alcista' if df_pe['Close'][i]>=df_pe['Open'][i] else 'bajista' for i in range(len(df_pe['Open']))]

# %%
df_pe.head()
# Out:
#             TimeStamp     Open     High      Low    Close  hora  dia   co  \
# 0 2019-07-07 21:00:00  1.12248  1.12275  1.12240  1.12275    21    6  2.7
# 1 2019-07-07 22:00:00  1.12278  1.12292  1.12256  1.12288    22    6  1.0
# 2 2019-07-07 23:00:00  1.12286  1.12286  1.12266  1.12268    23    6 -1.8
# 3 2019-07-08 00:00:00  1.12270  1.12298  1.12198  1.12212     0    0 -5.8
# 4 2019-07-08 01:00:00  1.12214  1.12283  1.12210  1.12276     1    0  6.2
#
#    mes sesion_vela  Amplitud de vela    HL Alcista o bajista
# 0    7   americana              -2.7   3.5           alcista
# 1    7        asia              -1.0   3.6           alcista
# 2    7        asia               1.8   2.0           bajista
# 3    7        asia               5.8  10.0           bajista
# 4    7        asia              -6.2   7.3           alcista

# %% [markdown]
# # EJERCICIO 6

# %% [markdown]
# <font size=4>(.5pt) ['sentido_c'] Conteo de velas consecutivas alcistas/bajistas.
#
# En el DataFrame de los precios OHLC, para cada renglon, ir acumulando el valor de velas consecutivas ALCISTAS o BAJISTAS e ir haciendo el conteo de ocurrencia para cada caso. Se comienza el conteo a partir de la primera repetición, por ejemplo, ['sentido_c'] tendrá un 2  en el tiempo t cuando en el tiempo t-2 y tiempo t-1 haya sido el mismo valor que en el tiempo t. En este ejemplo ['sentido_c'] tendría un 2 (en el tiempo t-2 fue la primera vela, y la vela en tiempo t-1 y en tiempo t fueron 2 velas fueron consecutivamente en el mismo sentido).

# %%
#funcion para ir contando el patron, si hay varios alcistas juntos se iran acumulando, y cuando se encuentre con un bajista 
#se reiniciara, de la misma manera cuando se encuentren varios bajistas juntos 
def al_baj(contador, a, b):
    if a == b:
        contador += 1
    else:
        contador = 0
    return  contador

contador = [0]

# %%
#Se agrega a la tabla y se implementa la funcion 
temp = [contador.append(al_baj(contador[i], df_pe['Alcista o bajista'][i], df_pe['Alcista o bajista'][i+1])) for i in range(len(df_pe['Alcista o bajista'])-1)]
df_pe['Patron'] = contador

# %%
df_pe
# Out:
#                TimeStamp     Open     High      Low    Close  hora  dia    co  \
# 0    2019-07-07 21:00:00  1.12248  1.12275  1.12240  1.12275    21    6   2.7
# 1    2019-07-07 22:00:00  1.12278  1.12292  1.12256  1.12288    22    6   1.0
# 2    2019-07-07 23:00:00  1.12286  1.12286  1.12266  1.12268    23    6  -1.8
# 3    2019-07-08 00:00:00  1.12270  1.12298  1.12198  1.12212     0    0  -5.8
# 4    2019-07-08 01:00:00  1.12214  1.12283  1.12210  1.12276     1    0   6.2
# 5    2019-07-08 02:00:00  1.12272  1.12272  1.12238  1.12260     2    0  -1.2
# 6    2019-07-08 03:00:00  1.12257  1.12294  1.12257  1.12284     3    0   2.7
# 7    2019-07-08 04:00:00  1.12282  1.12310  1.12251  1.12310     4    0   2.8
# 8    2019-07-08 05:00:00  1.12308  1.12326  1.12268  1.12298     5    0  -1.0
# 9    2019-07-08 06:00:00  1.12298  1.12298  1.12198  1.12204     6    0  -9.4
# 10   2019-07-08 07:00:00  1.12202  1.12328  1.12199  1.12318     7    0  11.6
# 11   2019-07-08 08:00:00  1.12316  1.12344  1.12287  1.12313     8    0  -0.3
# 12   2019-07-08 09:00:00  1.12311  1.12326  1.12258  1.12281     9    0  -3.0
# 13   2019-07-08 10:00:00  1.12284  1.12302  1.12150  1.12150    10    0 -13.4
# 14   2019-07-08 11:00:00  1.12147  1.12214  1.12134  1.12206    11    0   5.9
# 15   2019-07-08 12:00:00  1.12209  1.12270  1.12128  1.12234    12    0   2.5
# 16   2019-07-08 13:00:00  1.12232  1.12244  1.12148  1.12186    13    0  -4.6
# 17   2019-07-08 14:00:00  1.12188  1.12210  1.12098  1.12148    14    0  -4.0
# 18   2019-07-08 15:00:00  1.12151  1.12188  1.12074  1.12081    15    0  -7.0
# 19   2019-07-08 16:00:00  1.12084  1.12168  1.12071  1.12147    16    0   6.3
# 20   2019-07-08 17:00:00  1.12150  1.12208  1.12144  1.12154    17    0   0.4
# 21   2019-07-08 18:00:00  1.12151  1.12168  1.12116  1.12120    18    0  -3.1
# 22   2019-07-08 19:00:00  1.12118  1.12132  1.12091  1.12093    19    0  -2.5
# 23   2019-07-08 20:00:00  1.12095  1.12144  1.12084  1.12144    20    0   4.9
# 24   2019-07-08 21:00:00  1.12144  1.12176  1.12132  1.12158    21    0   1.4
# 25   2019-07-08 22:00:00  1.12156  1.12169  1.12152  1.12162    22    0   0.6
# 26   2019-07-08 23:00:00  1.12158  1.12162  1.12140  1.12154    23    0  -0.4
# 27   2019-07-09 00:00:00  1.12150  1.12188  1.12134  1.12154     0    1   0.4
# 28   2019-07-09 01:00:00  1.12158  1.12169  1.12098  1.12134     1    1  -2.4
# 29   2019-07-09 02:00:00  1.12132  1.12138  1.12117  1.12122     2    1  -1.0
# ...                  ...      ...      ...      ...      ...   ...  ...   ...
# 2591 2019-12-04 22:00:00  1.10780  1.10807  1.10780  1.10783    22    2   0.3
# 2592 2019-12-04 23:00:00  1.10785  1.10832  1.10785  1.10828    23    2   4.3
# 2593 2019-12-05 00:00:00  1.10825  1.10854  1.10800  1.10824     0    3  -0.1
# 2594 2019-12-05 01:00:00  1.10826  1.10848  1.10806  1.10842     1    3   1.6
# 2595 2019-12-05 02:00:00  1.10840  1.10841  1.10813  1.10827     2    3  -1.3
# 2596 2019-12-05 03:00:00  1.10830  1.10868  1.10830  1.10852     3    3   2.2
# 2597 2019-12-05 04:00:00  1.10849  1.10849  1.10829  1.10832     4    3  -1.7
# 2598 2019-12-05 05:00:00  1.10828  1.10854  1.10818  1.10832     5    3   0.4
# 2599 2019-12-05 06:00:00  1.10832  1.10838  1.10806  1.10824     6    3  -0.8
# 2600 2019-12-05 07:00:00  1.10826  1.10854  1.10798  1.10798     7    3  -2.8
# 2601 2019-12-05 08:00:00  1.10800  1.10914  1.10794  1.10892     8    3   9.2
# 2602 2019-12-05 09:00:00  1.10895  1.10930  1.10892  1.10924     9    3   2.9
# 2603 2019-12-05 10:00:00  1.10920  1.10923  1.10850  1.10887    10    3  -3.3
# 2604 2019-12-05 11:00:00  1.10885  1.10970  1.10846  1.10906    11    3   2.1
# 2605 2019-12-05 12:00:00  1.10908  1.11009  1.10904  1.10966    12    3   5.8
# 2606 2019-12-05 13:00:00  1.10964  1.10978  1.10888  1.10929    13    3  -3.5
# 2607 2019-12-05 14:00:00  1.10932  1.11044  1.10916  1.11000    14    3   6.8
# 2608 2019-12-05 15:00:00  1.11002  1.11037  1.10905  1.10928    15    3  -7.4
# 2609 2019-12-05 16:00:00  1.10926  1.11048  1.10914  1.11034    16    3  10.8
# 2610 2019-12-05 17:00:00  1.11036  1.11078  1.11010  1.11048    17    3   1.2
# 2611 2019-12-05 18:00:00  1.11046  1.11049  1.10993  1.11009    18    3  -3.7
# 2612 2019-12-05 19:00:00  1.11011  1.11012  1.10962  1.11004    19    3  -0.7
# 2613 2019-12-05 20:00:00  1.11002  1.11047  1.10962  1.11030    20    3   2.8
# 2614 2019-12-05 21:00:00  1.11027  1.11080  1.11020  1.11040    21    3   1.3
# 2615 2019-12-05 22:00:00  1.11040  1.11058  1.11038  1.11041    22    3   0.1
# 2616 2019-12-05 23:00:00  1.11043  1.11058  1.11040  1.11040    23    3  -0.3
# 2617 2019-12-06 00:00:00  1.11042  1.11055  1.11030  1.11030     0    4  -1.2
# 2618 2019-12-06 01:00:00  1.11033  1.11070  1.11033  1.11065     1    4   3.2
# 2619 2019-12-06 02:00:00  1.11068  1.11086  1.11066  1.11076     2    4   0.8
# 2620 2019-12-06 03:00:00  1.11074  1.11090  1.11070  1.11077     3    4   0.3
#
#       mes       sesion_vela  Amplitud de vela    HL Alcista o bajista  Patron
# 0       7         americana              -2.7   3.5           alcista       0
# 1       7              asia              -1.0   3.6           alcista       1
# 2       7              asia               1.8   2.0           bajista       0
# 3       7              asia               5.8  10.0           bajista       1
# 4       7              asia              -6.2   7.3           alcista       0
# 5       7              asia               1.2   3.4           bajista       0
# 6       7              asia              -2.7   3.7           alcista       0
# 7       7              asia              -2.8   5.9           alcista       1
# 8       7              asia               1.0   5.8           bajista       0
# 9       7              asia               9.4  10.0           bajista       1
# 10      7              asia             -11.6  12.9           alcista       0
# 11      7       asia_europa               0.3   5.7           bajista       0
# 12      7            europa               3.0   6.8           bajista       1
# 13      7            europa              13.4  15.2           bajista       2
# 14      7            europa              -5.9   8.0           alcista       0
# 15      7            europa              -2.5  14.2           alcista       1
# 16      7  europa_americana               4.6   9.6           bajista       0
# 17      7  europa_americana               4.0  11.2           bajista       1
# 18      7  europa_americana               7.0  11.4           bajista       2
# 19      7  europa_americana              -6.3   9.7           alcista       0
# 20      7         americana              -0.4   6.4           alcista       1
# 21      7         americana               3.1   5.2           bajista       0
# 22      7         americana               2.5   4.1           bajista       1
# 23      7         americana              -4.9   6.0           alcista       0
# 24      7         americana              -1.4   4.4           alcista       1
# 25      7              asia              -0.6   1.7           alcista       2
# 26      7              asia               0.4   2.2           bajista       0
# 27      7              asia              -0.4   5.4           alcista       0
# 28      7              asia               2.4   7.1           bajista       0
# 29      7              asia               1.0   2.1           bajista       1
# ...   ...               ...               ...   ...               ...     ...
# 2591   12              asia              -0.3   2.7           alcista       0
# 2592   12              asia              -4.3   4.7           alcista       1
# 2593   12              asia               0.1   5.4           bajista       0
# 2594   12              asia              -1.6   4.2           alcista       0
# 2595   12              asia               1.3   2.8           bajista       0
# 2596   12              asia              -2.2   3.8           alcista       0
# 2597   12              asia               1.7   2.0           bajista       0
# 2598   12              asia              -0.4   3.6           alcista       0
# 2599   12              asia               0.8   3.2           bajista       0
# 2600   12              asia               2.8   5.6           bajista       1
# 2601   12       asia_europa              -9.2  12.0           alcista       0
# 2602   12            europa              -2.9   3.8           alcista       1
# 2603   12            europa               3.3   7.3           bajista       0
# 2604   12            europa              -2.1  12.4           alcista       0
# 2605   12            europa              -5.8  10.5           alcista       1
# 2606   12  europa_americana               3.5   9.0           bajista       0
# 2607   12  europa_americana              -6.8  12.8           alcista       0
# 2608   12  europa_americana               7.4  13.2           bajista       0
# 2609   12  europa_americana             -10.8  13.4           alcista       0
# 2610   12         americana              -1.2   6.8           alcista       1
# 2611   12         americana               3.7   5.6           bajista       0
# 2612   12         americana               0.7   5.0           bajista       1
# 2613   12         americana              -2.8   8.5           alcista       0
# 2614   12         americana              -1.3   6.0           alcista       1
# 2615   12              asia              -0.1   2.0           alcista       2
# 2616   12              asia               0.3   1.8           bajista       0
# 2617   12              asia               1.2   2.5           bajista       1
# 2618   12              asia              -3.2   3.7           alcista       0
# 2619   12              asia              -0.8   2.0           alcista       1
# 2620   12              asia              -0.3   2.0           alcista       2
#
# [2621 rows x 14 columns]

# %% [markdown]
# # EJERCICIO 7

# %% [markdown]
# <font size=4>(1pt) Ventanas móviles de volatilidad
#
# Utiliza la columna de ['hl'] como una medida de "volatilidad" en pips de las velas. Con esta columna, genera las siguientes columnas haciendo una "ventana móvil" del máximo de esos últimos n valores. Las columnas serán 3, una para cada valor de la "volatilidad móvil" para 5, 25 y 50 velas de histórico respectivamente.
#
#
# •	['volatilidad_5']: Utilizando la información de las 5 anteriores velas.
#
# •	['volatilidad_25']: Utilizando la información de las 25 anteriores velas.
#
# •	['volatilidad_50']: Utilizando la información de las 50 anteriores velas.
#
# Recuerda que la "volatilidad" en una serie de tiempo financiera es, usualmente, la desviación estándar de los rendimientos, sin embargo, uno puedeo proponer otros "estadísticos" para representar la "variabilidad" entre los datos. En este caso, probaremos generar esta información sólo tomando en cuenta la columna ['hl']. Así que, no es necesario calcular rendimientos en esta ocasión.

# %%
#Ventanas moviles 
volatilidad_5 =df_pe['HL'].rolling(window = 5).std()
volatilidad_25 =df_pe['HL'].rolling(window = 25).std()
volatilidad_50 =df_pe['HL'].rolling(window = 50).std()

# %% [markdown]
# # EJERCICIO 8

# %% [markdown]
# <font size=4> (1pt) Gráfica con Plotly
#
# Realiza una propuesta de gráfica utilizando alguna de las columnas que has generado y la librería plotly. Las reglas son las siguientes:
# 1.	Tiene que tener título de gráfica
# 2.	Tiene que tener título de eje x y etiquetas de eje x
# 3.	Tiene que tener título de eje y y etiquetas de eje y
# 4.	Se debe de poder visualizar una leyenda (en cualquier posición)

# %%
#Gráfica interactiva  de el tipo de cambio EUR_USD a través del tiempo
import plotly.express as px
import plotly.graph_objects as go
cierre = df_pe.iloc[:,4]
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_pe['TimeStamp'], y=cierre,
                    mode='lines',
                    name='lines'))
fig.update_layout(title='Tipo de cambio a través del tiempo',
                   xaxis_title='Fecha',
                   yaxis_title='Tipo de cambio')
fig.show()
